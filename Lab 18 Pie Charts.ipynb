# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 173.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 184.7 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 126.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 160.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 165.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-03-13 19:17:13--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  56.5MB/s    in 2.7s
#
# 2025-03-13 19:17:16 (56.5 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
import pandas as pd
import matplotlib.pyplot as plt


if "DatabaseWantToWorkWith" in df.columns:
    db_series = df["DatabaseWantToWorkWith"].dropna().str.split(";").explode()

    db_counts = db_series.value_counts()

    top_5_dbs = db_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_dbs, labels=top_5_dbs.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Databases Respondents Want to Work With")
    plt.show()
else:
    print("La columna 'DatabaseWantToWorkWith' no se encuentra en el dataset.")

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
if "DevType" in df.columns:
    dev_series = df["DevType"].dropna().str.split(";").explode()

    dev_counts = dev_series.value_counts()


    top_5_dv_roles = dev_counts.nlargest(5)


    plt.figure(figsize=(8, 8))
    plt.pie(top_5_dev_roles, labels=top_5_dev_roles.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Developer Roles in Survey")
    plt.show()
else:
    print(" Column 'DevType' not found")

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
col_name = "OpSysProfessional use"
if col_name in df.columns:
    os_counts = df[col_name].dropna().value_counts()

    top_os = os_counts[os_counts / os_counts.sum() > 0.05]

    plt.figure(figsize=(8, 8))
    plt.pie(top_os, labels=top_os.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here

col_name = "LanguageHaveWorkedWith"
if col_name in df.columns:
    lang_series = df[col_name].dropna().str.split(";").explode()

    lang_counts = lang_series.value_counts()
 
    top_5_langs = lang_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_langs, labels=top_5_langs.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Programming Languages Respondents Have Worked With")
    plt.show()
else:
    print(f"The column '{col_name}' was not found.")

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
col_name = "NEWCollabToolsHaveWorkedWith"
if col_name in df.columns:

    tools_series = df[col_name].dropna().str.split(";").explode()

    tools_counts = tools_series.value_counts()

    top_5_tools = tools_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_tools, labels=top_5_tools.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Collaboration Tools Used Professionally")
    plt.show()
else:
    print(f"Column '{col_name}' not found.")

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
col_name = "LanguageAdmired"
if col_name in df.columns:
    admired_series = df[col_name].dropna().str.split(";").explode()

    admired_counts = admired_series.value_counts()

    top_5_admired = admired_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_admired, labels=top_5_admired.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Most Admired Programming Languages")
    plt.show()
else:
    print(f"Column'{col_name}' not found.")

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
col_name = "AIToolCurrentlyUsing"
if col_name in df.columns:
    
    ai_tools_series = df[col_name].dropna().str.split(";").explode()


    ai_tools_counts = ai_tools_series.value_counts()

    # Seleccionar las 5 más mencionadas
    top_5_ai_tools = ai_tools_counts.nlargest(5)

    # Crear el gráfico de pastel
    plt.figure(figsize=(8, 8))
    plt.pie(top_5_ai_tools, labels=top_5_ai_tools.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 AI Development Tools Used by Developers")
    plt.show()
else:
    print(f"La columna '{col_name}' no se encuentra en el dataset.")
# Out:
# La columna 'AIToolCurrentlyUsing' no se encuentra en el dataset.

# %%
# Mostrar los nombres de las columnas
print(df.columns)

# Buscar columnas que contengan palabras clave relacionadas con herramientas de IA
ai_keywords = ['AI', 'Tool', 'Machine Learning', 'Deep Learning', 'Neural Network', 'AITool']  # Ajusta según lo que esperes
matching_columns = [col for col in df.columns if any(keyword.lower() in col.lower() for keyword in ai_keywords)]

# Mostrar las columnas que coinciden
print("Posibles columnas relacionadas con herramientas de IA:", matching_columns)
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
# ...

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
col_name = "WebframeWantToWorkWith"
if col_name in df.columns:
   
    frameworks_series = df[col_name].dropna().str.split(";").explode()

    frameworks_counts = frameworks_series.value_counts()

    top_5_frameworks = frameworks_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_frameworks, labels=top_5_frameworks.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Web Frameworks Respondents Want to Work With")
    plt.show()
else:
    print(f"The column '{col_name}' not found.")

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
col_name = "EmbeddedWantToWorkWith"
if col_name in df.columns:

    embedded_tech_series = df[col_name].dropna().str.split(";").explode()

    embedded_tech_counts = embedded_tech_series.value_counts()

    top_5_embedded_tech = embedded_tech_counts.nlargest(5)

    plt.figure(figsize=(8, 8))
    plt.pie(top_5_embedded_tech, labels=top_5_embedded_tech.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Top 5 Most Desired Embedded Technologies")
    plt.show()
else:
    print(f"The column '{col_name}' was not found.")

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
